# %%
from matplotlib import pyplot as plt
import numpy as np

data = np.random.lognormal(mean=0.0, sigma=1.0, size=106)

x = np.sort(data)
y = 1. * np.arange(len(data)) / (len(data) - 1)

plt.plot(x, y)
plt.show()

print('50th percentile: ', np.percentile(data, 50))
# Out:
# 50th percentile:  1.0106930630600295
